# %% [markdown]
# # operasi biner

# %% [markdown]
# # Fitto Martcellindo 202131001

# %% [markdown]
# # import libary

# %%
import cv2 as marcel
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage import data 
from skimage.io import imread
from skimage.color import rgb2gray

# %% [markdown]
# # show image

# %%
pict1 = imread(fname = "noisy.jfif")
pict2 = imread(fname = "dog.jfif")

pict1 = marcel.cvtColor(pict1, marcel.COLOR_RGB2GRAY)
pict2 = marcel.cvtColor(pict2, marcel.COLOR_RGB2GRAY)

print("shape pict 1 : 0", pict1.shape)
print("shape pict 2 : 0", pict2.shape)

fig,axes = plt.subplots(1,2,figsize=(10,10))
ax= axes.ravel()

ax[0].imshow(pict1, cmap = 'gray')
ax[0].set_title('pict 1')
ax[1].imshow(pict2, cmap = 'gray')
ax[1].set_title('pict 2')
# Out:
# shape pict 1 : 0 (228, 221)
# shape pict 2 : 0 (213, 236)
# Text(0.5, 1.0, 'pict 2')

# %%
copypict1 = pict1.copy().astype(float)
copypict2 = pict2.copy().astype(float)

m1,n1 = copypict1.shape
ouput1 = np.empty([m1,n1])

m2,n2 = copypict2.shape
ouput2 = np.empty([m2,n2])

print('shape copy pict 1 : ',copypict1.shape)
print('shape copy pict 1 : ',copypict1.shape)

print('m1', m1)
print('n1', n1)


print('shape copy pict 2 : ',copypict2.shape)
print('shape copy pict 2 : ',copypict2.shape)

print('m2', m2)
print('n2', n2)
# Out:
# shape copy pict 1 :  (228, 221)
# shape copy pict 1 :  (228, 221)
# m1 228
# n1 221
# shape copy pict 2 :  (213, 236)
# shape copy pict 2 :  (213, 236)
# m2 213
# n2 236

# %% [markdown]
# # mean filtering

# %%
def mean_filter(image):
    copy_image = image.copy().astype(float)
    m,n = copy_image.shape
    output = np.empty_like(copy_image)
    
    for row in range (1, m-1):
        for col in range (1, n-1):
            total = copy_image[row-1, col-1] + copy_image[row-1, col+1] + \
                    copy_image[row, col-1] + copy_image[row, col] + copy_image[row, col+1] + \
                    copy_image[row+1, col-1] + copy_image[row+1, col] + copy_image[row+1, col+1]
            output[row, col] = total / 9
        return output

# %%
filtered_image1 = mean_filter(copypict1)
filtered_image2 = mean_filter(copypict2)

fig,axes = plt.subplots(2,2,figsize=(10,10))
ax= axes.ravel()

ax[0].imshow(pict1, cmap = 'gray')
ax[0].set_title('pict 1')

ax[1].imshow(filtered_image1, cmap = 'gray')
ax[1].set_title('pict 2')

ax[2].imshow(pict2, cmap = 'gray')
ax[2].set_title('pict 1')

ax[3].imshow(filtered_image2, cmap = 'gray')
ax[3].set_title('pict 2')

plt.tight_layout()

# %% [markdown]
# # Media  Filtering

# %%
median = marcel.imread('noisy.jfif')
median = marcel.cvtColor(median, marcel.COLOR_BGR2RGB)
median_after = marcel.medianBlur(median, 3)

# %%
plt.subplot(121),plt.imshow(median), plt.title('gambar asli')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(median), plt.title('gamabr filter')

plt.show()

# %% [markdown]
# # edge filtering

# %%
def filter_batas (data, filter_size):
    temp=[]
    indexer = filter_size
    new_image = data.copy()            
    nrow, ncol = data.shape
    
    for i in range(nrow):
        for j in range(ncol):
            for k in range(i-indexer, j+indexer+1):
                for m in range(j-indexer, j+indexer+1):
                    if (k > -1) and (k < nrow):
                        if (m > -1) and (m < ncol):
                            temp.append(data[k,m])
            temp.remove(data[i,j])
            max_value = max(temp)
            min_value = min(temp)
            if data[i,j] > max_value:
                new_image[i.j] =max_value
            elif data[i,j] <  min_value:
                new_image[i.j] = min_value
            temp = []
        return new_image.copy()

# %%
batas = marcel.imread('noisyimage.jpg')
batas_grey = marcel.cvtColor(batas, marcel.COLOR_BGR2GRAY)
filter_batas = filter_batas(batas_grey, 13)

plt.figure(figsize = (11,6))
plt.subplot(121),plt.imshow(batas), plt.title('gambar asli')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(filter_batas), plt.title('gamabr filter')

plt.show()
