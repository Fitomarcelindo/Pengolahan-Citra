# %% [markdown]
# # NAufal Adli |202131006

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('parkir.jpeg')

# %%
cv2.imshow('gambar asli parir',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # menampilkan tepi gambar

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edge = cv2.Canny (img, 100, 150)

# %%
cv2.imshow('gambar asli parir',edge)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fig, axs = plt.subplots(1,2, figsize =(10,10))
ax = axs.ravel()

ax[0].imshow(gray, cmap='gray')
ax[0].set_title('gambargrayscale')

ax[1].imshow(edge, cmap='gray')
ax[1].set_title('setelah edgeS')
# Out:
# Text(0.5, 1.0, 'setelah edgeS')

# %% [markdown]
# # menampilkan garis pada gambar

# %%
lines = cv2.HoughLinesP(edge, 1, np.pi/180, 30, maxLineGap=250)

img_line = img.copy()

# %%
for line in lines:
    x1,y1,x2,y2, = line[0]
    cv2.line(img_line, (x1,y1), (x2,y2), (0,0,255),1)

# %%
cv2.imshow('gambar asli parir',img_line)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray1 = cv2.cvtColor(img_line, cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1,2, figsize =(10,10))
ax = axs.ravel()

ax[0].imshow(gray, cmap='gray')
ax[0].set_title('gambargrayscale')

ax[1].imshow(gray1, cmap='gray')
ax[1].set_title('garis parkiran')
# Out:
# Text(0.5, 1.0, 'garis parkiran')
